# %%
import pandas as pd
import numpy as np

# %%
# Pandas Project

# 1. Using Real Estate Dataset, remove redundant Data
# 2. Find the total sales by residential type
# 3. Generate a new table that sort your data using column Sale Ratio from the highest to the minimum
# 4. Find the first 10 sales with the highest amount in a DataFrame
# 5. Return the min, max and the total sales of Estate
# 6. Congratulations on your new job as a data analyst in a Real Estate company, we realise that as years go by
# we are beginning to experience changes in our sales, can you draw a conclusion for your new employer,
# the effect of time on the company sales?

# 7. Kindly advise the company which town should they stop selling Estate
# 8. Base on your findings, advise the company which town should we continue selling our Real Estate
# 9. We have different properties in our company, which property will you advise us to stop selling
# and which will you advise us to sell more of it

# 10. SAVE YOUR ANALYSIS WITH YOUR NAME AND YOUR STUDENT ID.

# %% [markdown]
# <h1>READING THE FILE</h1>

# %%
df = pd.read_csv("Real_Estate_Sales.csv")  
df
# Out:
# C:\Users\timia\AppData\Local\Temp\ipykernel_19008\2745147701.py:1: DtypeWarning: Columns (8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Real_Estate_Sales.csv")
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997213 entries, 0 to 997212
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     997213 non-null  int64
#  1   List Year         997213 non-null  int64
#  2   Date Recorded     997211 non-null  object
#  3   Town              997213 non-null  object
#  4   Address           997162 non-null  object
#  5   Assessed Value    997213 non-null  float64
#  6   Sale Amount       997213 non-null  float64
#  7   Sales Ratio       997213 non-null  float64
#  8   Property Type     614767 non-null  object
#  9   Residential Type  608904 non-null  object
#  10  Non Use Code      289681 non-null  object
#  11  Assessor Remarks  149864 non-null  object
#  12  OPM remarks       9934 non-null    object
#  13  Location          197697 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 106.5+ MB

# %%
df.describe()
# Out:
#        Serial Number      List Year  Assessed Value   Sale Amount  \
# count   9.972130e+05  997213.000000    9.972130e+05  9.972130e+05
# mean    4.311864e+05    2010.189829    2.791437e+05  3.911512e+05
# std     6.549219e+06       6.237877    1.670610e+06  5.347270e+06
# min     0.000000e+00    2001.000000    0.000000e+00  0.000000e+00
# 25%     3.044400e+04    2004.000000    8.760000e+04  1.400000e+05
# 50%     7.030300e+04    2010.000000    1.383900e+05  2.250000e+05
# 75%     1.518780e+05    2016.000000    2.255600e+05  3.650000e+05
# max     2.000500e+09    2020.000000    8.815100e+08  5.000000e+09
#
#         Sales Ratio
# count  9.972130e+05
# mean   1.044637e+01
# std    1.890192e+03
# min    0.000000e+00
# 25%    4.867000e-01
# 50%    6.246000e-01
# 75%    7.852761e-01
# max    1.226420e+06

# %% [markdown]
# <h1> CLEANING THE DATA BY DROPPING REDUNDANT ROWS AND COLUMNS</h1>

# %%
# In the  columns , we can see that there are two tables in the columns that are redundant
# so we have to drop them totally because they have no value

df.drop(columns ='OPM remarks', axis = 1, inplace=True)

# %%
df.drop(columns = 'Location', axis=1, inplace = True)

# %%
df.drop(columns = 'Non Use Code', axis=1, inplace = True)

# %%
df.drop(columns = 'Assessor Remarks', axis=1, inplace = True)

# %%
df
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 0             2020348       2020    09/13/2021        Ansonia
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# ...               ...        ...           ...            ...
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
# 997212         190344       2019    12/20/2019        Milford
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 0             230 WAKELEE AVE        150500.0     325000.0     0.463000
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# ...

# %% [markdown]
# <h1>CHECKING FOR NULL VALUES</h1>

# %%
df.isnull()
# Out:
#         Serial Number  List Year  Date Recorded   Town  Address  \
# 0               False      False          False  False    False
# 1               False      False          False  False    False
# 2               False      False          False  False    False
# 3               False      False          False  False    False
# 4               False      False          False  False    False
# ...               ...        ...            ...    ...      ...
# 997208          False      False          False  False    False
# 997209          False      False          False  False    False
# 997210          False      False          False  False    False
# 997211          False      False          False  False    False
# 997212          False      False          False  False    False
#
#         Assessed Value  Sale Amount  Sales Ratio  Property Type  \
# 0                False        False        False          False
# 1                False        False        False          False
# ...

# %%
df.head(50)
# Out:
#     Serial Number  List Year Date Recorded         Town  \
# 0         2020348       2020    09/13/2021      Ansonia
# 1           20002       2020    10/02/2020      Ashford
# 2          200212       2020    03/09/2021         Avon
# 3          200243       2020    04/13/2021         Avon
# 4          200377       2020    07/02/2021         Avon
# 5          200109       2020    12/09/2020         Avon
# 6         2020180       2020    03/01/2021       Berlin
# 7         2020313       2020    07/01/2021       Berlin
# 8          200097       2020    06/04/2021      Bethany
# 9           20139       2020    12/16/2020       Bethel
# 10         200086       2020    08/10/2021    Bethlehem
# 11        2000381       2020    09/13/2021   Bloomfield
# 12         200258       2020    01/22/2021     Branford
# 13         200804       2020    09/28/2021     Branford
# 14         201295       2020    09/09/2021      Bristol
# 15         200032       2020    10/08/2020      Bristol
# ...

# %%
df.drop(index = 0, axis = 0, inplace=True)

# %%
df.drop(index = 997212, axis = 0, inplace = True)

# %%
df
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# 5              200109       2020    12/09/2020           Avon
# ...               ...        ...           ...            ...
# 997207         190272       2019    08/03/2020         Wilton
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# 2            5 CHESTNUT DRIVE        130400.0     179900.0     0.724800
# ...

# %%
df.head(50)
# Out:
#     Serial Number  List Year Date Recorded         Town  \
# 1           20002       2020    10/02/2020      Ashford
# 2          200212       2020    03/09/2021         Avon
# 3          200243       2020    04/13/2021         Avon
# 4          200377       2020    07/02/2021         Avon
# 5          200109       2020    12/09/2020         Avon
# 6         2020180       2020    03/01/2021       Berlin
# 7         2020313       2020    07/01/2021       Berlin
# 8          200097       2020    06/04/2021      Bethany
# 9           20139       2020    12/16/2020       Bethel
# 10         200086       2020    08/10/2021    Bethlehem
# 11        2000381       2020    09/13/2021   Bloomfield
# 12         200258       2020    01/22/2021     Branford
# 13         200804       2020    09/28/2021     Branford
# 14         201295       2020    09/09/2021      Bristol
# 15         200032       2020    10/08/2020      Bristol
# 16         200354       2020    12/29/2020      Bristol
# ...

# %% [markdown]
# ### CHECKING FOR DUPLICATED

# %%
df.duplicated()
# Out:
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
#           ...
# 997207    False
# 997208    False
# 997209    False
# 997210    False
# 997211    False
# Length: 997211, dtype: bool

# %% [markdown]
# <h1>DROPPING DUPLCATES</h1>

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# 5              200109       2020    12/09/2020           Avon
# ...               ...        ...           ...            ...
# 997207         190272       2019    08/03/2020         Wilton
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# 2            5 CHESTNUT DRIVE        130400.0     179900.0     0.724800
# ...

# %%
df.head(50)
# Out:
#     Serial Number  List Year Date Recorded         Town  \
# 1           20002       2020    10/02/2020      Ashford
# 2          200212       2020    03/09/2021         Avon
# 3          200243       2020    04/13/2021         Avon
# 4          200377       2020    07/02/2021         Avon
# 5          200109       2020    12/09/2020         Avon
# 6         2020180       2020    03/01/2021       Berlin
# 7         2020313       2020    07/01/2021       Berlin
# 8          200097       2020    06/04/2021      Bethany
# 9           20139       2020    12/16/2020       Bethel
# 10         200086       2020    08/10/2021    Bethlehem
# 11        2000381       2020    09/13/2021   Bloomfield
# 12         200258       2020    01/22/2021     Branford
# 13         200804       2020    09/28/2021     Branford
# 14         201295       2020    09/09/2021      Bristol
# 15         200032       2020    10/08/2020      Bristol
# 16         200354       2020    12/29/2020      Bristol
# ...

# %%
df[df['Town']== '***Unknown***']
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 444657          70086       2007    12/18/2007  ***Unknown***
#
#                 Address  Assessed Value  Sale Amount  Sales Ratio  \
# 444657  18 MATHIEU LANE         66540.0     282450.0     0.235582
#
#         Property Type Residential Type
# 444657  Single Family    Single Family

# %%
df.drop(index=444657, axis=0, inplace=True)

# %% [markdown]
# <h1>DROPPING THE NULL VALUES</h1>

# %%
df.dropna(axis = 0, inplace = True)

# %%
df
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 1               20002       2020    10/02/2020        Ashford
# 2              200212       2020    03/09/2021           Avon
# 3              200243       2020    04/13/2021           Avon
# 4              200377       2020    07/02/2021           Avon
# 5              200109       2020    12/09/2020           Avon
# ...               ...        ...           ...            ...
# 997207         190272       2019    08/03/2020         Wilton
# 997208         190272       2019    06/24/2020     New London
# 997209         190284       2019    11/27/2019      Waterbury
# 997210         190129       2019    04/27/2020  Windsor Locks
# 997211         190504       2019    06/03/2020     Middletown
#
#                       Address  Assessed Value  Sale Amount  Sales Ratio  \
# 1             390 TURNPIKE RD        253000.0     430000.0     0.588300
# 2            5 CHESTNUT DRIVE        130400.0     179900.0     0.724800
# ...

# %%
df.groupby('Residential Type')

# %%
df.groupby('Residential Type').count()
# Out:
#                   Serial Number  List Year  Date Recorded    Town  Address  \
# Residential Type
# Condo                    117779     117779         117779  117779   117779
# Four Family                2418       2418           2418    2418     2418
# Single Family            445013     445013         445013  445013   445013
# Three Family              14081      14081          14081   14081    14081
# Two Family                29608      29608          29608   29608    29608
#
#                   Assessed Value  Sale Amount  Sales Ratio  Property Type
# Residential Type
# Condo                     117779       117779       117779         117779
# Four Family                 2418         2418         2418           2418
# Single Family             445013       445013       445013         445013
# Three Family               14081        14081        14081          14081
# Two Family                 29608        29608        29608          29608

# %% [markdown]
# <h1>2. FIND THE TOTAL SALES BY RESIDENTIAL TYPE</h1>

# %%
df.groupby('Residential Type')[['Sale Amount']].sum()
# Out:
#                    Sale Amount
# Residential Type
# Condo             3.265330e+10
# Four Family       7.615052e+08
# Single Family     1.783571e+11
# Three Family      2.868236e+09
# Two Family        6.127529e+09

# %% [markdown]
# ##  3. Generate a new table that sort your data using column Sale Ratio from the highest to the minimum

# %%
df = df.sort_values(['Sales Ratio'], ascending = False)
df
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 421304          60043       2006    03/19/2007      Salisbury
# 424013          60190       2006    03/02/2007        Newtown
# 425795          60213       2006    03/29/2007        Newtown
# 893093         180020       2018    10/29/2018   Beacon Falls
# 422591          60442       2006    09/14/2007       Guilford
# ...               ...        ...           ...            ...
# 839990         170051       2017    03/22/2018   Beacon Falls
# 476684          71068       2007    09/30/2008  West Hartford
# 397780          60241       2006    09/05/2007  New Fairfield
# 503965           8638       2008    08/17/2009        Meriden
# 514920          90048       2009    04/28/2010   Beacon Falls
#
#                        Address  Assessed Value  Sale Amount  Sales Ratio  \
# 421304             209 MAIN ST       1226420.0          1.0    1226420.0
# ...

# %%
df.dropna(axis = 0, inplace = True)

# %%
df
# Out:
#         Serial Number  List Year Date Recorded           Town  \
# 421304          60043       2006    03/19/2007      Salisbury
# 424013          60190       2006    03/02/2007        Newtown
# 425795          60213       2006    03/29/2007        Newtown
# 893093         180020       2018    10/29/2018   Beacon Falls
# 422591          60442       2006    09/14/2007       Guilford
# ...               ...        ...           ...            ...
# 839990         170051       2017    03/22/2018   Beacon Falls
# 476684          71068       2007    09/30/2008  West Hartford
# 397780          60241       2006    09/05/2007  New Fairfield
# 503965           8638       2008    08/17/2009        Meriden
# 514920          90048       2009    04/28/2010   Beacon Falls
#
#                        Address  Assessed Value  Sale Amount  Sales Ratio  \
# 421304             209 MAIN ST       1226420.0          1.0    1226420.0
# ...

# %% [markdown]
# ## 4. Find the first 10 sales with the highest amount in a DataFrame

# %%
sales = df.sort_values(['Sale Amount'], ascending = False).head(10)
sales
# Out:
#         Serial Number  List Year Date Recorded        Town  \
# 60894        20200078       2020    07/06/2021  Willington
# 65620        20200102       2020    09/28/2021  Willington
# 957543         191094       2019    08/12/2020     Norwalk
# 655816         130446       2013    04/11/2014   Greenwich
# 33575         2000806       2020    01/15/2021    Stamford
# 30399         2000810       2020    01/15/2021    Stamford
# 47544         2000807       2020    01/15/2021    Stamford
# 40034         2000801       2020    01/15/2021    Stamford
# 32999         2000819       2020    01/15/2021    Stamford
# 28506         2000814       2020    01/15/2021    Stamford
#
#                         Address  Assessed Value  Sale Amount  Sales Ratio  \
# 60894            224 RIVER ROAD        223070.0  318790019.0     0.000700
# 65620   7 TOLLAND TURNPIKE ROAD        112040.0  194149073.0     0.000577
# 957543            33 ORCHARD ST        507580.0  157000000.0     0.003200
# ...

# %% [markdown]
# ## Return the min, max and the total sales of Estate

# %%
s_total = df['Sale Amount'].sum()
s_total
# Out:
# 220767693520.26

# %%
mi_total = df['Sale Amount'].min()
mi_total
# Out:
# 0.0

# %%
mx_total = df['Sale Amount'].max()
mx_total
# Out:
# 318790019.0

# %% [markdown]
# ## can you draw a conclusion for your new employer,  the effect of time on the company sales?

# %%
correlation = df.corr(method='spearman')
correlation
# Out:
# C:\Users\timia\AppData\Local\Temp\ipykernel_19008\3563869834.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = df.corr(method='spearman')
#                 Serial Number  List Year  Assessed Value  Sale Amount  \
# Serial Number        1.000000   0.617797       -0.015265     0.022382
# List Year            0.617797   1.000000       -0.029814     0.043957
# Assessed Value      -0.015265  -0.029814        1.000000     0.822214
# Sale Amount          0.022382   0.043957        0.822214     1.000000
# Sales Ratio         -0.083280  -0.163835        0.093335    -0.382794
#
#                 Sales Ratio
# Serial Number     -0.083280
# List Year         -0.163835
# Assessed Value     0.093335
# Sale Amount       -0.382794
# Sales Ratio        1.000000

# %% [markdown]
# <strong>looking at the table above, we have the cross relationship betweeen the List Year and The Sales Ratio to be Negative, which means that the time has no effect on the company sales</strong>

# %% [markdown]
# <h1>7. Kindly advise the company which town should they stop selling Estate</h1>

# %%
df.groupby('Town')['Sales Ratio'].sum().sort_values(ascending=True)
# Out:
# Town
# Union           1.015329e+02
# Eastford        2.052644e+02
# Warren          2.349656e+02
# Franklin        2.387194e+02
# Bozrah          2.619247e+02
#                     ...
# Mansfield       1.643493e+05
# Guilford        2.032997e+05
# Beacon Falls    3.860138e+05
# Newtown         7.839283e+05
# Salisbury       1.227461e+06
# Name: Sales Ratio, Length: 169, dtype: float64

# %% [markdown]
# <strong>My conclusion is that the Real Estate company should stop selling their Estate to the 'UNION' Town,
# Because,  It has the Lowest Sales</strong>

# %% [markdown]
# <h1>8. Base on your findings, advise the company which town should we continue selling our Real Estate</h1>

# %%
df.groupby('Town')['Sales Ratio'].sum().sort_values(ascending=False)
# Out:
# Town
# Salisbury       1.227461e+06
# Newtown         7.839283e+05
# Beacon Falls    3.860138e+05
# Guilford        2.032997e+05
# Mansfield       1.643493e+05
#                     ...
# Bozrah          2.619247e+02
# Franklin        2.387194e+02
# Warren          2.349656e+02
# Eastford        2.052644e+02
# Union           1.015329e+02
# Name: Sales Ratio, Length: 169, dtype: float64

# %% [markdown]
# <strong> My advise to the Real Estate Company is that,
#     The company should continue selling their  Estates in 'Salisbury' Town, Due to the High rate of Sales which is
#     present in the table below</strong>

# %% [markdown]
# <h1>9. We have different properties in our company, which property will you advise us to stop selling
# and which will you advise us to sell more of it</h1>

# %%
df.groupby('Property Type')['Sales Ratio'].sum().sort_values(ascending=True)
# Out:
# Property Type
# Four Family      3.056720e+03
# Three Family     1.817615e+04
# Two Family       3.203342e+04
# Residential      4.272107e+04
# Condo            9.062680e+04
# Single Family    3.259113e+06
# Name: Sales Ratio, dtype: float64

# %% [markdown]
# <strong> Based on the Table above, we can see that the Property Type, " Four Family" has a lower sales ratio and brought the least profit to the company. Hereby my advise is that the company should stop selling " FOUR FAMILY PROPERTY TYPE".</strong>

# %%
df.groupby('Property Type')['Sales Ratio'].sum().sort_values(ascending=False)
# Out:
# Property Type
# Single Family    3.259113e+06
# Condo            9.062680e+04
# Residential      4.272107e+04
# Two Family       3.203342e+04
# Three Family     1.817615e+04
# Four Family      3.056720e+03
# Name: Sales Ratio, dtype: float64

# %% [markdown]
# <strong>Based on the Table above, we can see that the Property Type, " Single Family" has a Higher sales ratio and brought the Highest profit to the company. Hereby my advise is that the company should Continue selling " Single family type".</strong>
